# %% [markdown]
# # Load the Data
# Load NASDAQ - composite data to test the fitting

# %%
import pandas as pd
df = pd.read_csv("normalized_data.csv")

# %% [markdown]
# # Test the analysis

# %%
from data_analyzer import *
from IPython.display import display, Markdown

# %%
windows_to_test = [None] + [2**(x) for x in range(12,2,-1)]
windows_to_test
# Out:
# [None, 4096, 2048, 1024, 512, 256, 128, 64, 32, 16, 8]

# %%
for w in windows_to_test:
    display(Markdown("# Using Windows Size: %s"%w))
    get_estimated_time(df, "Date", "Close", w, debug = True)
# Out:
# # Using Windows Size: None
# y = 2.2902674159258543e-10 * x + -0.05740796809418443
# Date esitmated : 2116-04-22
# Days left: 35372
# # Using Windows Size: 4096
# y = 3.9285836125299955e-10 * x + -0.23918123816206183
# Date esitmated : 2069-12-14
# Days left: 18442
# # Using Windows Size: 2048
# y = 2.0842125256884775e-09 * x + -2.5068870233711174
# Date esitmated : 2023-04-27
# Days left: 1409
# # Using Windows Size: 1024
# y = 3.1750461836415246e-09 * x + -4.148278834124409
# Date esitmated : 2021-05-20
# Days left: 702
# # Using Windows Size: 512
# y = 4.4288903886875906e-09 * x + -6.028883410588068
# Date esitmated : 2020-04-16
# Days left: 303
# # Using Windows Size: 256
# y = -5.546200342828073e-10 * x + 1.61719774734169
# Date esitmated : 2005-04-07
# Days left: -5184
# The line is never going to intercept the max
# # Using Windows Size: 128
# y = 1.2555431440428169e-08 * x + -18.74479342626084
# Date esitmated : 2019-11-01
# Days left: 136
# # Using Windows Size: 64
# ...
